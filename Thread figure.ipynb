# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Calculator-project-in-python-language/blob/main/Thread%20figure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import threadfigure

while True:
    print("\n--- 3D Geometry Calculator ---")
    print("1. Cube")
    print("2. Cuboid")
    print("3. Cylinder")
    print("4. Cone")
    print("5. Sphere")
    print("6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 6:
        print("Exiting program...")
        break

    print("\nSelect Operation:")
    print("1. Curved Surface Area (CSA)")
    print("2. Total Surface Area (TSA)")
    print("3. Volume")

    op = int(input("Enter operation: "))

    # ----------------- CUBE -----------------
    if choice == 1:
        a = float(input("Enter side of cube: "))

        if op == 1:
            result = 4 * a * a
        elif op == 2:
            result = 6 * a * a
        elif op == 3:
            result = a ** 3

    # ----------------- CUBOID -----------------
    elif choice == 2:
        l = float(input("Enter length: "))
        b = float(input("Enter breadth: "))
        h = float(input("Enter height: "))

        if op == 1:
            result = 2 * h * (l + b)
        elif op == 2:
            result = 2 * (l*b + b*h + h*l)
        elif op == 3:
            result = l * b * h

    # ----------------- CYLINDER -----------------
    elif choice == 3:
        r = float(input("Enter radius: "))
        h = float(input("Enter height: "))

        if op == 1:
            result = 2 * math.pi * r * h
        elif op == 2:
            result = 2 * math.pi * r * (h + r)
        elif op == 3:
            result = math.pi * r**2 * h

    # ----------------- CONE -----------------
    elif choice == 4:
        r = float(input("Enter radius: "))

        if op == 1 or op == 2:
            l = float(input("Enter slant height: "))
        if op == 3:
            h = float(input("Enter height: "))

        if op == 1:
            result = math.pi * r * l
        elif op == 2:
            result = math.pi * r * (l + r)
        elif op == 3:
            result = (1/3) * math.pi * r**2 * h

    # ----------------- SPHERE -----------------
    elif choice == 5:
        r = float(input("Enter radius: "))

        if op == 1 or op == 2:
            result = 4 * math.pi * r**2
        elif op == 3:
            result = (4/3) * math.pi * r**3

    else:
        print("Invalid choice!")
        continue

    print("Result =", result)
